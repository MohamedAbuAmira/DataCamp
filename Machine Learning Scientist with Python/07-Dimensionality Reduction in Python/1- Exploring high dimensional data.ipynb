# %% [markdown]
# You'll be introduced to the concept of dimensionality reduction and will learn when an why this is important. You'll learn the difference between feature selection and feature extraction and will apply both techniques for data exploration. The chapter ends with a lesson on t-SNE, a powerful feature extraction technique that will allow you to visualize a high-dimensional dataset.

# %% [markdown]
# # 1- introduction

# %% [markdown]
# video

# %% [markdown]
# # 2- Finding the number of dimensions in a dataset

# %% [markdown]
# A larger sample of the Pokemon dataset has been loaded for you as the Pandas dataframe pokemon_df.
#
# How many dimensions, or columns are in this dataset?

# %%
import pandas as pd
import numpy as np

pokemon_df = pd.read_csv('datasets/pokemon.csv')

# %%
pokemon_df.shape
# Out:
# (800, 13)

# %%
df=pokemon_df.head(n=160)

# %% [markdown]
# # 3- Removing features without variance

# %% [markdown]
# <p>A sample of the Pokemon dataset has been loaded as <code>pokemon_df</code>. To get an idea of which features have little variance you should use the IPython Shell to calculate summary statistics on this sample. Then adjust the code to create a smaller, easier to understand, dataset.</p>

# %% [markdown]
# - Use the .describe() method to find the numeric feature without variance and remove its name from the list assigned to number_cols.

# %%
df.describe()
# Out:
#                 #       Total          HP      Attack     Defense     Sp. Atk  \
# count  160.000000  160.000000  160.000000  160.000000  160.000000  160.000000
# mean    73.050000  418.693750   64.725000   74.712500   70.268750   69.687500
# std     43.614348  107.323293   27.917883   28.827701   28.880086   32.208477
# min      1.000000  195.000000   10.000000    5.000000    5.000000   15.000000
# 25%     34.750000  322.250000   45.000000   52.000000   50.000000   45.000000
# 50%     73.500000  430.000000   60.000000   71.000000   65.000000   65.000000
# 75%    111.250000  500.000000   80.000000   95.000000   85.000000   90.000000
# max    147.000000  640.000000  250.000000  155.000000  180.000000  175.000000
#
#           Sp. Def       Speed  Generation
# count  160.000000  160.000000       160.0
# mean    68.056250   71.243750         1.0
# std     25.237051   28.929484         0.0
# min     20.000000   15.000000         1.0
# 25%     50.000000   49.500000         1.0
# ...

# %%
# Remove the feature without variance from this list
number_cols = ['HP', 'Attack', 'Defense','Generation']

# %%
#after remove 'Generation', becuase it with std=0, means no variance
number_cols = ['HP', 'Attack', 'Defense']

# %% [markdown]
# - Combine the two lists of feature names to sub-select the chosen features from pokemon_df.
# - Find the non-numeric feature without variance and remove its name from the list assigned to non_number_cols

# %%
# Leave this list as is for now
non_number_cols = ['Name', 'Type 1', 'Legendary']

# %%
#for non-numeric data
df.describe(exclude=[np.number])
# Out:
#           Name Type 1  Type 2 Legendary
# count      160    160      76       160
# unique     160     15      13         2
# top     Cubone  Water  Poison     False
# freq         1     31      22       157

# %%
# Leave this list as is
number_cols = ['HP', 'Attack', 'Defense']

# Remove the feature without variance from previuse list
non_number_cols = ['Name','Type 1']

# Create a new dataframe by subselecting the chosen features
df_selected = pokemon_df[number_cols + non_number_cols]

# Prints the first 5 lines of the new dataframe
print(df_selected.head())
# Out:
#    HP  Attack  Defense                   Name Type 1
# 0  45      49       49              Bulbasaur  Grass
# 1  60      62       63                Ivysaur  Grass
# 2  80      82       83               Venusaur  Grass
# 3  80     100      123  VenusaurMega Venusaur  Grass
# 4  39      52       43             Charmander   Fire

# %% [markdown]
# # 4- Feature selection vs feature extraction

# %% [markdown]
# video

# %% [markdown]
# # 5- Visually detecting redundant features

# %% [markdown]
# <p>Data visualization is a crucial step in any data exploration.
# Let&apos;s use Seaborn to explore some samples of the US Army ANSUR body measurement dataset.</p>
# <p>Two data samples have been pre-loaded as <code>ansur_df_1</code> and  <code>ansur_df_2</code>.</p>
# <p>Seaborn has been imported as <code>sns</code>.</p>

# %%
#importing data 

import seaborn as sns
import matplotlib.pyplot as plt

ansur_df_1 = pd.read_csv('datasets/ansur_df_1.csv')
ansur_df_2 = pd.read_csv('datasets/ansur_df_2.csv')

# %% [markdown]
# - Create a pairplot of the ansur_df_1 data sample and color the points using the 'Gender' feature.

# %%
# Create a pairplot and color the points using the 'Gender' feature
sns.pairplot(ansur_df_1, hue='Gender', diag_kind='hist')

# Show the plot
plt.show()

# %% [markdown]
# - Two features are basically duplicates, remove one of them from the dataset.

# %%
# Remove one of the redundant features
reduced_df = ansur_df_1.drop('body_height', axis=1)

# Create a pairplot and color the points using the 'Gender' feature
sns.pairplot(reduced_df, hue='Gender')

# Show the plot
plt.show()

# %% [markdown]
# - Now create a pairplot of the ansur_df_2 data sample and color the points using the 'Gender' feature.

# %%
# Create a pairplot and color the points using the 'Gender' feature
sns.pairplot(ansur_df_2, hue='Gender', diag_kind='hist')


# Show the plot
plt.show()

# %% [markdown]
# - One feature has no variance, remove it from the dataset

# %%
# Remove the redundant feature
reduced_df = ansur_df_2.drop('n_legs', axis=1)

# Create a pairplot and color the points using the 'Gender' feature
sns.pairplot(reduced_df, hue='Gender', diag_kind='hist')

# Show the plot
plt.show()

# %% [raw]
# Correct, the body height (inches) and stature (meters) hold the same information in a different unit + all the individuals in the second sample have two legs.

# %% [markdown]
# # 6- Advantage of feature selection

# %% [markdown]
# What advantage does feature selection have over feature extraction?

# %% [markdown]
# - Feature selection allows you to do a stronger reduction in the number of dimensions.
#
# - Less information is lost during feature selection compared to feature extraction.
#
# ###### - The selected features remain unchanged, and are therefore easy to interpret.
#
# - Models will never overfit to a sub-selected dataset.

# %% [markdown]
# # 7- t-SNE visualization of high-dimensional data

# %% [markdown]
# video

# %% [markdown]
# # 8- Fitting t-SNE to the ANSUR data

# %% [markdown]
# <p>t-SNE is a great technique for visual exploration of high dimensional datasets. In this exercise, you&apos;ll apply it to the ANSUR dataset. You&apos;ll remove non-numeric columns from the pre-loaded dataset <code>df</code> and fit <code>TSNE</code> to his numeric dataset.</p>

# %% [markdown]
# <ul>
# <li>Drop the non-numeric columns from the dataset.</li>
# <li>Create a <code>TSNE</code> model with learning rate 50.</li>
# <li>Fit and transform the model on the numeric dataset.</li>
# </ul>

# %%
# Non-numerical columns in the dataset
non_numeric = ['Branch', 'Gender', 'Component']

# Drop the non-numerical columns from df
df_numeric = df.drop(non_numeric, axis=1)

# Create a t-SNE model with learning rate 50
m = TSNE(learning_rate=50)

# Fit and transform the t-SNE model on the numeric dataset
tsne_features = m.fit_transform(df_numeric)
print(tsne_features.shape)

# %%
<script.py> output:
    (6068, 2)

# %% [raw]
# Good job! t-SNE reduced the more than 90 features in the dataset to just 2 which you can now plot

# %% [markdown]
# # 9- t-SNE visualisation of dimensionality

# %% [markdown]
# <p>Time to look at the results of your hard work. In this exercise, you will visualize the output of t-SNE dimensionality reduction on the combined male and female Ansur dataset.
# You&apos;ll create 3 scatterplots of the 2 t-SNE features (<code>&apos;x&apos;</code> and <code>&apos;y&apos;</code>) which were added to the dataset <code>df</code>. In each scatterplot you&apos;ll color the points according to a different categorical variable.</p>
# <p><code>seaborn</code> has already been imported as <code>sns</code> and <code>matplotlib.pyplot</code> as <code>plt</code>.</p>

# %% [markdown]
# <ul>
# <li>Use seaborn&apos;s <code>sns.scatterplot</code> to create the plot.</li>
# <li>Color the points by <code>&apos;Component&apos;</code>.</li>
# </ul>

# %%
# Color the points according to Army Component
sns.scatterplot(x="x", y="y", hue='Component', data=df)

# Show the plot
plt.show()

# %% [markdown]
# <img alt="plot" role="presentation" src="data:image/svg+xml;base64,..." data-test-id="plot-image" data-cy="plot-image" class="dc-u-stretch dc-u-wh-100pc">

# %% [markdown]
# <ul>
# <li>Color the points of the scatterplot by <code>&apos;Branch&apos;</code>.</li>
# </ul>

# %%
# Color the points by Army Branch
sns.scatterplot(x="x", y="y", hue='Branch', data=df)

# Show the plot
plt.show()

# %% [markdown]
# <img alt="plot" role="presentation" src="data:image/svg+xml;base64,..." data-test-id="plot-image" data-cy="plot-image" class="dc-u-stretch dc-u-wh-100pc">

# %% [markdown]
# <ul>
# <li>Color the points of the scatterplot by <code>&apos;Gender&apos;</code>.</li>
# </ul>

# %%
# Color the points by Gender
sns.scatterplot(x="x", y="y", hue='Gender', data=df)

# Show the plot
plt.show()

# %% [markdown]
# <img alt="plot" role="presentation" src="data:image/svg+xml;base64,..." data-test-id="plot-image" data-cy="plot-image" class="dc-u-stretch dc-u-wh-100pc">

# %% [raw]
# Eureka! There is a Male and a Female cluster. t-SNE found these gender differences in body shape without being told about them explicitly! From the second plot you learned there are more males in the Combat Arms Branch.
